# %% [markdown]
# # Notebook 01: Dataset Exploration
#
# This notebook covers data exploration of the original lecturer dataset, scraped CSV files, and external public Kiswahili-English parallel corpora.
#
# ## Objectives:
# 1. Load and inspect the source datasets.
# 2. Visualize data distributions (document sizes, character counts, text lengths).
# 3. Highlight candidate PSA patterns and term frequencies.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# TODO: Load data from data/raw/ and perform basic EDA
