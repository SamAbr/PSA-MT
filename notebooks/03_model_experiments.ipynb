# %% [markdown]
# # Notebook 03: Model Experiments
#
# This notebook contains model experiments for fine-tuning pre-trained Seq2Seq translation models (e.g. NLLB-200) on our Kiswahili-English PSA corpus.
#
# ## Objectives:
# 1. Initialize model tokenizer and model weights.
# 2. Prepare PyTorch Dataset/DataLoader configurations.
# 3. Run training loops and track loss metrics.

# %%
# TODO: Import transformers library and load pre-trained checkpoints
